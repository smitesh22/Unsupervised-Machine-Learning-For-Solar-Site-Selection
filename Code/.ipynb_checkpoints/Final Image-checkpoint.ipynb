# %% [markdown]
# # Set Up the meta

# %%
from osgeo import ogr, osr

# %%
driver = ogr.GetDriverByName('ESRI Shapefile')

# %%
dataset = driver.Open("/home/smitesh22/Data/GIS Extracted/N19E072_wgs84/planet_72,19_73,20-shp/shape/", 0)

# %%
layer_types = {
              0:'places',
              1: 'railway',
              2:'landuse',
              3:'natural',
              4:'point',
              5:'waterway',
              6:'road',
              7:'buildings'}

# %%
layer_metadata = {}
for num in layer_types:
    layer = dataset.GetLayer(num)
    
    attributes = []
    for feature in layer:
        attributes.append(feature.items())
    meta = set()
    
    for attr in attributes:
        #print(attr['type'])
        meta.add(attr['type'])
        
        
    layer_metadata[layer_types[num]] = meta

# %%
layer_metadata
# Out:
# {'places': {'borough',
#   'city',
#   'farm',
#   'hamlet',
#   'island',
#   'locality',
#   'neighbourhood',
#   'plot',
#   'suburb',
#   'town',
#   'village',
#   'yes'},
#  'railway': {'abandoned',
#   'construction',
#   'disused',
#   'miniature',
#   'monorail',
#   'platform',
#   'platform_edge',
#   'proposed',
#   'rail',
#   'subway',
#   'traverser',
#   'turntable',
#   'workshop'},
#  'landuse': {'allotments',
#   'aquaculture',
#   'barren',
#   'basin',
#   'brownfield',
#   'cemetery',
#   'commercial',
#   'construction',
#   'education',
#   'farmland',
#   'farmyard',
#   'garages',
#   'garden',
#   'grass',
#   'green',
#   'greenfield',
#   'industrial',
#   'landfill',
#   'meadow',
#   'military',
#   'orchard',
#   'parking',
#   'plant_nursery',
#   'quarry',
#   'railway',
#   'recreation_groun',
#   'religious',
#   'reservoir',
#   'residential',
#   'retail',
#   'salt_pond',
#   'saltpond',
#   'used by school a',
#   'vacant',
#   'village_green',
#   'yes'},
#  'natural': {'forest', 'park', 'water'},
#  'point': {'Drinking Water F',
#   'The Wall',
#   'animal_boarding',
#   'animal_shelter',
#   'antenna',
#   'apartment',
#   'archaeological_s',
#   'art_school',
#   'arts_centre',
#   'artwork',
#   'atm',
#   'attraction',
#   'bank',
#   'bar',
#   'battlefield',
#   'bbq',
#   'beauty',
#   'bench',
#   'bicycle_parking',
#   'bicycle_repair_s',
#   'blood_bank',
#   'buffer_stop',
#   'bureau_de_change',
#   'bus_station',
#   'bus_stop',
#   'cafe',
#   'camp_site',
#   'car_rental',
#   'car_wash',
#   'castle',
#   'charging_station',
#   'childcare',
#   'chimney',
#   'cinema',
#   'clinic',
#   'clothes',
#   'clubhouse',
#   'college',
#   'community_centre',
#   'compressed_air',
#   'construction',
#   'coworking_space',
#   'crane',
#   'crematorium',
#   'cross',
#   'crossing',
#   'dancing_school',
#   'dentist',
#   'derail',
#   'doctors',
#   'drinking_water',
#   'driving_school',
#   'electronics',
#   'electronics_repa',
#   'elevator',
#   'events_venue',
#   'fast_food',
#   'ferry_terminal',
#   'fire_station',
#   'flagpole',
#   'food_court',
#   'fort',
#   'fountain',
#   'fuel',
#   'gallery',
#   'guest_house',
#   'health_post',
#   'hospital',
#   'hostel',
#   'hotel',
#   'hunting_stand',
#   'ice_cream',
#   'information',
#   'internet_cafe',
#   'jeweller',
#   'kindergarten',
#   'language_school',
#   'level_crossing',
#   'library',
#   'lighthouse',
#   'marketplace',
#   'mast',
#   'memorial',
#   'mess',
#   'mini_roundabout',
#   'monument',
#   'motel',
#   'motorcycle_parki',
#   'motorway_junctio',
#   'museum',
#   'nightclub',
#   'parking',
#   'parking_entrance',
#   'passing_place',
#   'pharmacy',
#   'phone service pr',
#   'picnic_site',
#   'place_of_worship',
#   'platform',
#   'police',
#   'post_box',
#   'post_office',
#   'prep_school',
#   'pub',
#   'public',
#   'public_building',
#   'railway_crossing',
#   'reception_desk',
#   'rest_area',
#   'restaurant',
#   'ruins',
#   'school',
#   'shelter',
#   'signal',
#   'social_centre',
#   'social_facility',
#   'spa',
#   'station',
#   'steps',
#   'stop',
#   'storage_tank',
#   'street_lamp',
#   'studio',
#   'subway_entrance',
#   'surveillance',
#   'switch',
#   'taxi',
#   'technical_statio',
#   'telephone',
#   'telephone_exchan',
#   'theatre',
#   'theme_park',
#   'toilets',
#   'toll_gantry',
#   'tomb',
#   'tower',
#   'townhall',
#   'traffic_signals',
#   'training',
#   'turning_circle',
#   'turning_loop',
#   'unclassified',
#   'university',
#   'vending_machine',
#   'veterinary',
#   'viewpoint',
#   'waste_basket',
#   'waste_disposal',
#   'water_point',
#   'water_tap',
#   'water_tower',
#   'water_well',
#   'wayside_cross',
#   'wayside_shrine',
#   'works',
#   'wreck',
#   'yes'},
#  'waterway': {'canal', 'dam', 'dock', 'drain', 'river', 'stream', 'weir'},
#  'road': {'bridleway',
#   'bus_stop',
#   'construction',
#   'cycleway',
#   'elevator',
#   'footway',
#   'living_street',
#   'motorway',
#   'motorway_link',
#   'path',
#   'pedestrian',
#   'primary',
#   'primary_link',
#   'proposed',
#   'residential',
#   'secondary',
#   'secondary_link',
#   'service',
#   'services',
#   'steps',
#   'tertiary',
#   'tertiary_link',
#   'track',
#   'trunk',
#   'trunk_link',
#   'unclassified'},
#  'buildings': {'Chemtex_House',
#   'NVR Hospital',
#   None,
#   'SHIV AANGAN BUIL',
#   'apartment',
#   'apartments',
#   'aquarium',
#   'arts_centre',
#   'attraction',
#   'bank',
#   'bar',
#   'blood_bank',
#   'building',
#   'bungalow',
#   'bus_station',
#   'cabin',
#   'cafe',
#   'canteen',
#   'car_wash',
#   'central_office',
#   'chapel',
#   'childcare',
#   'church',
#   'cinema',
#   'city_gate',
#   'civic',
#   'clinic',
#   'clubhouse',
#   'collapsed',
#   'college',
#   'commercial',
#   'community_centre',
#   'construction',
#   'courthouse',
#   'cowshed',
#   'depot',
#   'detached',
#   'dormitory',
#   'events_venue',
#   'factory',
#   'fast_food',
#   'ferry_terminal',
#   'fire_station',
#   'food_court',
#   'fort',
#   'fuel',
#   'gallery',
#   'garage',
#   'government',
#   'greenhouse',
#   'guest_house',
#   'hangar',
#   'hospital',
#   'hostel',
#   'hotel',
#   'house',
#   'hut',
#   'industrial',
#   'kindergarten',
#   'library',
#   'lighthouse',
#   'mall',
#   'manufacture',
#   'marketplace',
#   'memorial',
#   'mosque',
#   'motel',
#   'motorcycle_parki',
#   'no',
#   'office',
#   'outdoor',
#   'parking',
#   'part',
#   'pharmacy',
#   'pier',
#   'place_of_worship',
#   'police',
#   'post_office',
#   'prep_school',
#   'public',
#   'public_building',
#   'pumping_station',
#   'residential',
#   'restaurant',
#   'retail',
#   'roof',
#   'ruins',
#   'school',
#   'service',
#   'shed',
#   'shelter',
#   'shop',
#   'social_centre',
#   'social_facility',
#   'sports_centre',
#   'stadium',
#   'stage',
#   'storage_tank',
#   'stupa',
#   'substation',
#   'supermarket',
#   'temple',
#   'terrace',
#   'theatre',
#   'toilets',
#   'tomb',
#   'tower',
#   'townhall',
#   'train_station',
#   'transportation',
#   'undefined',
#   'university',
#   'veterinary',
#   'wall',
#   'warehouse',
#   'water_tower',
#   'works',
#   'workshop',
#   'yes',
#   'yes,_hotel,_comm'}}

# %% [markdown]
# ### Create Plot

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
shapefile_path = "/home/smitesh22/Data/GIS Extracted/N19E072_wgs84/planet_72,19_73,20-shp/shape/landuse.shp"
gdf = gpd.read_file(shapefile_path)

# %%
gdf
# Out:
#           osm_id                    name              type  \
# 0       27036055             JW Marriott        commercial
# 1       27054927  Shopper Stop - Andheri            retail
# 2       27083476            Ranima Films       residential
# 3       31144246             Otters Club  recreation_groun
# 4       31291194     St Theresa's Ground  recreation_groun
# ...          ...                     ...               ...
# 4310  1187689780                     NaN       residential
# 4311  1187689781                     NaN       residential
# 4312  1187689785                     NaN  recreation_groun
# 4313  1188130826           IVY DREAMLAND       residential
# 4314  1188386895   Vitta Sanchay Society       residential
#
#                                                geometry
# 0     POLYGON ((72.82508 19.10217, 72.82684 19.10246...
# 1     POLYGON ((72.84234 19.11510, 72.84235 19.11552...
# 2     POLYGON ((72.81305 19.13517, 72.81314 19.13504...
# 3     POLYGON ((72.82136 19.06081, 72.82136 19.06028...
# 4     POLYGON ((72.83303 19.06316, 72.83297 19.06281...
# ...                                                 ...
# 4310  POLYGON ((72.89086 19.14789, 72.89077 19.14773...
# 4311  POLYGON ((72.89197 19.14673, 72.89256 19.14713...
# 4312  POLYGON ((72.89327 19.14757, 72.89352 19.14762...
# 4313  POLYGON ((72.82452 19.35389, 72.82555 19.35289...
# 4314  POLYGON ((72.88723 19.03118, 72.88727 19.03093...
#
# [4315 rows x 4 columns]

# %%
gdf = gdf.to_crs("EPSG:3857")

# %%
#100 meters buffer
gdf['geometry'] = gdf['geometry'].buffer(100)

# %%
import matplotlib.pyplot as plt

# Filter out 'vacant' and 'barren' types
filtered_gdf = gdf[~gdf['type'].isin(['vacant', 'barren'])]

# Plot the filtered GeoDataFrame in red
ax = filtered_gdf.plot(color='red', figsize=(10, 10))

plt.show()

# %%
gdf
# Out:
#           osm_id                    name              type  \
# 0       27036055             JW Marriott        commercial
# 1       27054927  Shopper Stop - Andheri            retail
# 2       27083476            Ranima Films       residential
# 3       31144246             Otters Club  recreation_groun
# 4       31291194     St Theresa's Ground  recreation_groun
# ...          ...                     ...               ...
# 4310  1187689780                     NaN       residential
# 4311  1187689781                     NaN       residential
# 4312  1187689785                     NaN  recreation_groun
# 4313  1188130826           IVY DREAMLAND       residential
# 4314  1188386895   Vitta Sanchay Society       residential
#
#                                                geometry
# 0     POLYGON ((8106753.109 2166946.977, 8106751.479...
# 1     POLYGON ((8108672.537 2168479.525, 8108671.852...
# 2     POLYGON ((8105461.291 2170942.685, 8105481.918...
# 3     POLYGON ((8106437.694 2162196.343, 8106505.710...
# 4     POLYGON ((8107747.978 2162472.887, 8107818.654...
# ...                                                 ...
# 4310  POLYGON ((8114139.000 2172198.314, 8114125.823...
# 4311  POLYGON ((8114207.865 2172173.104, 8114190.844...
# 4312  POLYGON ((8114385.641 2172400.517, 8114394.067...
# 4313  POLYGON ((8106744.659 2196735.713, 8106913.007...
# 4314  POLYGON ((8113782.925 2158706.024, 8113827.620...
#
# [4315 rows x 4 columns]

# %%
import re
import pandas as pd
import glob

def get_suitable_area(shapefile_path, buffer):
    """
    params : shapefile_path : location where shp files for the geolocations are present
             buffer : buffer distance in meters
    
    output : Geodataframe with features needed to be considered along with a buffer of 100 meters
    
    """
    
    gdfs = []
    
    #shapefile_path = "/home/smitesh22/Data/GIS Extracted/N19E072_wgs84/planet_72,19_73,20-shp/shape/landuse.shp"
    
    #get all the shapefiles available for the geolocation
    shape_files = glob.glob(f'{shapefile_path}*.shp')
    
    #loop over each shape file
    for shape_file in shape_files:
        
        match = re.search(r'([^/]+)\.shp$', shape_file)
        #feature to identiy layer
        feature = match.group(1)
        
        gdf = gpd.read_file(shapefile_path)
        
        #EPSG:3395 (World Mercator) uses metric system
        gdf = gdf.to_crs(epsg=3395)
        
        #add a buffer of 100 meters
        gdf['geometry'] = gdf['geometry'].buffer(buffer)
        
        #conditions on each layer to select CERTAIN attribute values only
        if feature == "places":
            pass
        elif feature == "landuse":
            filtered_gdf = gdf[~gdf['type'].isin(['vacant', 'barren'])]
        elif feature == "natural":
            pass
        
        filtered_gdf = gdf
        
        filtered_gdf['feature'] = feature
        
        gdfs.append(filtered_gdf)
        
        # Concatenate all the GeoDataFrames in the list
        combined_gdf = pd.concat(gdfs, ignore_index=True)
        
        print(combined_gdf)
    return combined_gdf

# %%
combined_gdf = get_suitable_area("/home/smitesh22/Data/GIS Extracted/N19E072_wgs84/planet_72,19_73,20-shp/shape/")
# Out:
#          osm_id              name           type  population  \
# 0      16173235            Mumbai           city  12442373.0
# 1     245659664    Ambedkar Nagar  neighbourhood         NaN
# 2     245659875  New Police Lines       locality         NaN
# 3     245659921       Police Camp       locality         NaN
# 4     245660095      Kidwai Nagar       locality         NaN
# ..          ...               ...            ...         ...
# 896 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 897 -1861921692   Gopinath Colony  neighbourhood         NaN
# 898 -1860575188     Shastri Nagar  neighbourhood         NaN
# 899 -1856561246      Gautam Nagar  neighbourhood         NaN
# 900 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                               geometry feature
# 0    POLYGON ((8113761.442 2150225.852, 8113756.627...  places
# 1    POLYGON ((8110347.685 2141499.627, 8110342.870...  places
# 2    POLYGON ((8110332.334 2141789.095, 8110327.519...  places
# 3    POLYGON ((8106750.986 2141839.138, 8106746.171...  places
# 4    POLYGON ((8110956.781 2142018.856, 8110951.966...  places
# ..                                                 ...     ...
# 896  POLYGON ((8111521.972 2146341.643, 8111517.157...  places
# 897  POLYGON ((8111553.320 2146374.889, 8111548.505...  places
# 898  POLYGON ((8110792.741 2151902.613, 8110787.925...  places
# 899  POLYGON ((8115656.434 2156606.920, 8115651.619...  places
# 900  POLYGON ((8115474.905 2158378.206, 8115470.090...  places
#
# [901 rows x 6 columns]
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 1797 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 1798 -1861921692   Gopinath Colony  neighbourhood         NaN
# 1799 -1860575188     Shastri Nagar  neighbourhood         NaN
# 1800 -1856561246      Gautam Nagar  neighbourhood         NaN
# 1801 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry   feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...    places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...    places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...    places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...    places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...    places
# ...                                                 ...       ...
# 1797  POLYGON ((8111521.972 2146341.643, 8111517.157...  railways
# 1798  POLYGON ((8111553.320 2146374.889, 8111548.505...  railways
# 1799  POLYGON ((8110792.741 2151902.613, 8110787.925...  railways
# 1800  POLYGON ((8115656.434 2156606.920, 8115651.619...  railways
# 1801  POLYGON ((8115474.905 2158378.206, 8115470.090...  railways
#
# [1802 rows x 6 columns]
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 2698 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 2699 -1861921692   Gopinath Colony  neighbourhood         NaN
# 2700 -1860575188     Shastri Nagar  neighbourhood         NaN
# 2701 -1856561246      Gautam Nagar  neighbourhood         NaN
# 2702 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry  feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...   places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...   places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...   places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...   places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...   places
# ...                                                 ...      ...
# 2698  POLYGON ((8111521.972 2146341.643, 8111517.157...  landuse
# 2699  POLYGON ((8111553.320 2146374.889, 8111548.505...  landuse
# 2700  POLYGON ((8110792.741 2151902.613, 8110787.925...  landuse
# 2701  POLYGON ((8115656.434 2156606.920, 8115651.619...  landuse
# 2702  POLYGON ((8115474.905 2158378.206, 8115470.090...  landuse
#
# [2703 rows x 6 columns]
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 3599 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 3600 -1861921692   Gopinath Colony  neighbourhood         NaN
# 3601 -1860575188     Shastri Nagar  neighbourhood         NaN
# 3602 -1856561246      Gautam Nagar  neighbourhood         NaN
# 3603 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry  feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...   places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...   places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...   places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...   places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...   places
# ...                                                 ...      ...
# 3599  POLYGON ((8111521.972 2146341.643, 8111517.157...  natural
# 3600  POLYGON ((8111553.320 2146374.889, 8111548.505...  natural
# 3601  POLYGON ((8110792.741 2151902.613, 8110787.925...  natural
# 3602  POLYGON ((8115656.434 2156606.920, 8115651.619...  natural
# 3603  POLYGON ((8115474.905 2158378.206, 8115470.090...  natural
#
# [3604 rows x 6 columns]
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 4500 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 4501 -1861921692   Gopinath Colony  neighbourhood         NaN
# 4502 -1860575188     Shastri Nagar  neighbourhood         NaN
# 4503 -1856561246      Gautam Nagar  neighbourhood         NaN
# 4504 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...  places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...  places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...  places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...  places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...  places
# ...                                                 ...     ...
# 4500  POLYGON ((8111521.972 2146341.643, 8111517.157...  points
# 4501  POLYGON ((8111553.320 2146374.889, 8111548.505...  points
# 4502  POLYGON ((8110792.741 2151902.613, 8110787.925...  points
# 4503  POLYGON ((8115656.434 2156606.920, 8115651.619...  points
# 4504  POLYGON ((8115474.905 2158378.206, 8115470.090...  points
#
# [4505 rows x 6 columns]
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 5401 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 5402 -1861921692   Gopinath Colony  neighbourhood         NaN
# 5403 -1860575188     Shastri Nagar  neighbourhood         NaN
# 5404 -1856561246      Gautam Nagar  neighbourhood         NaN
# 5405 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry    feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...     places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...     places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...     places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...     places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...     places
# ...                                                 ...        ...
# 5401  POLYGON ((8111521.972 2146341.643, 8111517.157...  waterways
# 5402  POLYGON ((8111553.320 2146374.889, 8111548.505...  waterways
# 5403  POLYGON ((8110792.741 2151902.613, 8110787.925...  waterways
# 5404  POLYGON ((8115656.434 2156606.920, 8115651.619...  waterways
# 5405  POLYGON ((8115474.905 2158378.206, 8115470.090...  waterways
#
# [5406 rows x 6 columns]
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 6302 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 6303 -1861921692   Gopinath Colony  neighbourhood         NaN
# 6304 -1860575188     Shastri Nagar  neighbourhood         NaN
# 6305 -1856561246      Gautam Nagar  neighbourhood         NaN
# 6306 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...  places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...  places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...  places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...  places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...  places
# ...                                                 ...     ...
# 6302  POLYGON ((8111521.972 2146341.643, 8111517.157...   roads
# 6303  POLYGON ((8111553.320 2146374.889, 8111548.505...   roads
# 6304  POLYGON ((8110792.741 2151902.613, 8110787.925...   roads
# 6305  POLYGON ((8115656.434 2156606.920, 8115651.619...   roads
# 6306  POLYGON ((8115474.905 2158378.206, 8115470.090...   roads
#
# [6307 rows x 6 columns]
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 7203 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 7204 -1861921692   Gopinath Colony  neighbourhood         NaN
# 7205 -1860575188     Shastri Nagar  neighbourhood         NaN
# 7206 -1856561246      Gautam Nagar  neighbourhood         NaN
# 7207 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry    feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...     places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...     places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...     places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...     places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...     places
# ...                                                 ...        ...
# 7203  POLYGON ((8111521.972 2146341.643, 8111517.157...  buildings
# 7204  POLYGON ((8111553.320 2146374.889, 8111548.505...  buildings
# 7205  POLYGON ((8110792.741 2151902.613, 8110787.925...  buildings
# 7206  POLYGON ((8115656.434 2156606.920, 8115651.619...  buildings
# 7207  POLYGON ((8115474.905 2158378.206, 8115470.090...  buildings
#
# [7208 rows x 6 columns]

# %%
combined_gdf
# Out:
#           osm_id              name           type  population  \
# 0       16173235            Mumbai           city  12442373.0
# 1      245659664    Ambedkar Nagar  neighbourhood         NaN
# 2      245659875  New Police Lines       locality         NaN
# 3      245659921       Police Camp       locality         NaN
# 4      245660095      Kidwai Nagar       locality         NaN
# ...          ...               ...            ...         ...
# 7203 -1861921693     Saibaba Nagar  neighbourhood         NaN
# 7204 -1861921692   Gopinath Colony  neighbourhood         NaN
# 7205 -1860575188     Shastri Nagar  neighbourhood         NaN
# 7206 -1856561246      Gautam Nagar  neighbourhood         NaN
# 7207 -1856431809      Maroshi Pada  neighbourhood         NaN
#
#                                                geometry    feature
# 0     POLYGON ((8113761.442 2150225.852, 8113756.627...     places
# 1     POLYGON ((8110347.685 2141499.627, 8110342.870...     places
# 2     POLYGON ((8110332.334 2141789.095, 8110327.519...     places
# 3     POLYGON ((8106750.986 2141839.138, 8106746.171...     places
# 4     POLYGON ((8110956.781 2142018.856, 8110951.966...     places
# ...                                                 ...        ...
# 7203  POLYGON ((8111521.972 2146341.643, 8111517.157...  buildings
# 7204  POLYGON ((8111553.320 2146374.889, 8111548.505...  buildings
# 7205  POLYGON ((8110792.741 2151902.613, 8110787.925...  buildings
# 7206  POLYGON ((8115656.434 2156606.920, 8115651.619...  buildings
# 7207  POLYGON ((8115474.905 2158378.206, 8115470.090...  buildings
#
# [7208 rows x 6 columns]

# %%
combined_gdf.plot(color='red', buffer = 100)

# Optional: Add titles, labels, or other customizations
plt.title('My Geospatial Plot')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# Calculate the total area
total_area = combined_gdf['geometry'].area.sum()

# Print the result
print(f"The total area is {total_area/1000} square units.")
# Out:
# The total area is 22608241.51985726 square units.

# %%
# Convert the GeoDataFrame to a geographic CRS if it's not already
# WGS 84 (EPSG:4326) is a common choice that uses degrees for latitude and longitude
combined_gdf = combined_gdf.to_crs(epsg=4326)

# Plot the data
combined_gdf.plot(color='red')

# Add labels for clarity
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Ensure that the axes are equally scaled
plt.axis('equal')

# Show the plot
plt.show()
