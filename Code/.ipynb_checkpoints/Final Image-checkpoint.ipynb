# %% [markdown]
# # Set Up the meta

# %%
from osgeo import ogr, osr

# %%
driver = ogr.GetDriverByName('ESRI Shapefile')

# %%
dataset = driver.Open("/home/smitesh22/Data/GIS Extracted/N19E072_wgs84/planet_72,19_73,20-shp/shape/", 0)

# %%
layer_types = {
              0:'places',
              1: 'railway',
              2:'landuse',
              3:'natural',
              4:'point',
              5:'waterway',
              6:'road',
              7:'buildings'}

# %%
layer_metadata = {}
for num in layer_types:
    layer = dataset.GetLayer(num)
    
    attributes = []
    for feature in layer:
        attributes.append(feature.items())
    meta = set()
    
    for attr in attributes:
        #print(attr['type'])
        meta.add(attr['type'])
        
        
    layer_metadata[layer_types[num]] = meta

# %%
layer_metadata
# Out:
# {'places': {'borough',
#   'city',
#   'farm',
#   'hamlet',
#   'island',
#   'locality',
#   'neighbourhood',
#   'plot',
#   'suburb',
#   'town',
#   'village',
#   'yes'},
#  'railway': {'abandoned',
#   'construction',
#   'disused',
#   'miniature',
#   'monorail',
#   'platform',
#   'platform_edge',
#   'proposed',
#   'rail',
#   'subway',
#   'traverser',
#   'turntable',
#   'workshop'},
#  'landuse': {'allotments',
#   'aquaculture',
#   'barren',
#   'basin',
#   'brownfield',
#   'cemetery',
#   'commercial',
#   'construction',
#   'education',
#   'farmland',
#   'farmyard',
#   'garages',
#   'garden',
#   'grass',
#   'green',
#   'greenfield',
#   'industrial',
#   'landfill',
#   'meadow',
#   'military',
#   'orchard',
#   'parking',
#   'plant_nursery',
#   'quarry',
#   'railway',
#   'recreation_groun',
#   'religious',
#   'reservoir',
#   'residential',
#   'retail',
#   'salt_pond',
#   'saltpond',
#   'used by school a',
#   'vacant',
#   'village_green',
#   'yes'},
#  'natural': {'forest', 'park', 'water'},
#  'point': {'Drinking Water F',
#   'The Wall',
#   'animal_boarding',
#   'animal_shelter',
#   'antenna',
#   'apartment',
#   'archaeological_s',
#   'art_school',
#   'arts_centre',
#   'artwork',
#   'atm',
#   'attraction',
#   'bank',
#   'bar',
#   'battlefield',
#   'bbq',
#   'beauty',
#   'bench',
#   'bicycle_parking',
#   'bicycle_repair_s',
#   'blood_bank',
#   'buffer_stop',
#   'bureau_de_change',
#   'bus_station',
#   'bus_stop',
#   'cafe',
#   'camp_site',
#   'car_rental',
#   'car_wash',
#   'castle',
#   'charging_station',
#   'childcare',
#   'chimney',
#   'cinema',
#   'clinic',
#   'clothes',
#   'clubhouse',
#   'college',
#   'community_centre',
#   'compressed_air',
#   'construction',
#   'coworking_space',
#   'crane',
#   'crematorium',
#   'cross',
#   'crossing',
#   'dancing_school',
#   'dentist',
#   'derail',
#   'doctors',
#   'drinking_water',
#   'driving_school',
#   'electronics',
#   'electronics_repa',
#   'elevator',
#   'events_venue',
#   'fast_food',
#   'ferry_terminal',
#   'fire_station',
#   'flagpole',
#   'food_court',
#   'fort',
#   'fountain',
#   'fuel',
#   'gallery',
#   'guest_house',
#   'health_post',
#   'hospital',
#   'hostel',
#   'hotel',
#   'hunting_stand',
#   'ice_cream',
#   'information',
#   'internet_cafe',
#   'jeweller',
#   'kindergarten',
#   'language_school',
#   'level_crossing',
#   'library',
#   'lighthouse',
#   'marketplace',
#   'mast',
#   'memorial',
#   'mess',
#   'mini_roundabout',
#   'monument',
#   'motel',
#   'motorcycle_parki',
#   'motorway_junctio',
#   'museum',
#   'nightclub',
#   'parking',
#   'parking_entrance',
#   'passing_place',
#   'pharmacy',
#   'phone service pr',
#   'picnic_site',
#   'place_of_worship',
#   'platform',
#   'police',
#   'post_box',
#   'post_office',
#   'prep_school',
#   'pub',
#   'public',
#   'public_building',
#   'railway_crossing',
#   'reception_desk',
#   'rest_area',
#   'restaurant',
#   'ruins',
#   'school',
#   'shelter',
#   'signal',
#   'social_centre',
#   'social_facility',
#   'spa',
#   'station',
#   'steps',
#   'stop',
#   'storage_tank',
#   'street_lamp',
#   'studio',
#   'subway_entrance',
#   'surveillance',
#   'switch',
#   'taxi',
#   'technical_statio',
#   'telephone',
#   'telephone_exchan',
#   'theatre',
#   'theme_park',
#   'toilets',
#   'toll_gantry',
#   'tomb',
#   'tower',
#   'townhall',
#   'traffic_signals',
#   'training',
#   'turning_circle',
#   'turning_loop',
#   'unclassified',
#   'university',
#   'vending_machine',
#   'veterinary',
#   'viewpoint',
#   'waste_basket',
#   'waste_disposal',
#   'water_point',
#   'water_tap',
#   'water_tower',
#   'water_well',
#   'wayside_cross',
#   'wayside_shrine',
#   'works',
#   'wreck',
#   'yes'},
#  'waterway': {'canal', 'dam', 'dock', 'drain', 'river', 'stream', 'weir'},
#  'road': {'bridleway',
#   'bus_stop',
#   'construction',
#   'cycleway',
#   'elevator',
#   'footway',
#   'living_street',
#   'motorway',
#   'motorway_link',
#   'path',
#   'pedestrian',
#   'primary',
#   'primary_link',
#   'proposed',
#   'residential',
#   'secondary',
#   'secondary_link',
#   'service',
#   'services',
#   'steps',
#   'tertiary',
#   'tertiary_link',
#   'track',
#   'trunk',
#   'trunk_link',
#   'unclassified'},
#  'buildings': {'Chemtex_House',
#   'NVR Hospital',
#   None,
#   'SHIV AANGAN BUIL',
#   'apartment',
#   'apartments',
#   'aquarium',
#   'arts_centre',
#   'attraction',
#   'bank',
#   'bar',
#   'blood_bank',
#   'building',
#   'bungalow',
#   'bus_station',
#   'cabin',
#   'cafe',
#   'canteen',
#   'car_wash',
#   'central_office',
#   'chapel',
#   'childcare',
#   'church',
#   'cinema',
#   'city_gate',
#   'civic',
#   'clinic',
#   'clubhouse',
#   'collapsed',
#   'college',
#   'commercial',
#   'community_centre',
#   'construction',
#   'courthouse',
#   'cowshed',
#   'depot',
#   'detached',
#   'dormitory',
#   'events_venue',
#   'factory',
#   'fast_food',
#   'ferry_terminal',
#   'fire_station',
#   'food_court',
#   'fort',
#   'fuel',
#   'gallery',
#   'garage',
#   'government',
#   'greenhouse',
#   'guest_house',
#   'hangar',
#   'hospital',
#   'hostel',
#   'hotel',
#   'house',
#   'hut',
#   'industrial',
#   'kindergarten',
#   'library',
#   'lighthouse',
#   'mall',
#   'manufacture',
#   'marketplace',
#   'memorial',
#   'mosque',
#   'motel',
#   'motorcycle_parki',
#   'no',
#   'office',
#   'outdoor',
#   'parking',
#   'part',
#   'pharmacy',
#   'pier',
#   'place_of_worship',
#   'police',
#   'post_office',
#   'prep_school',
#   'public',
#   'public_building',
#   'pumping_station',
#   'residential',
#   'restaurant',
#   'retail',
#   'roof',
#   'ruins',
#   'school',
#   'service',
#   'shed',
#   'shelter',
#   'shop',
#   'social_centre',
#   'social_facility',
#   'sports_centre',
#   'stadium',
#   'stage',
#   'storage_tank',
#   'stupa',
#   'substation',
#   'supermarket',
#   'temple',
#   'terrace',
#   'theatre',
#   'toilets',
#   'tomb',
#   'tower',
#   'townhall',
#   'train_station',
#   'transportation',
#   'undefined',
#   'university',
#   'veterinary',
#   'wall',
#   'warehouse',
#   'water_tower',
#   'works',
#   'workshop',
#   'yes',
#   'yes,_hotel,_comm'}}

# %% [markdown]
# ### Create Plot

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
shapefile_path = "/home/smitesh22/Data/GIS Extracted/N19E072_wgs84/planet_72,19_73,20-shp/shape/landuse.shp"
gdf = gpd.read_file(shapefile_path)

# %%
gdf
# Out:
#           osm_id                    name              type  \
# 0       27036055             JW Marriott        commercial
# 1       27054927  Shopper Stop - Andheri            retail
# 2       27083476            Ranima Films       residential
# 3       31144246             Otters Club  recreation_groun
# 4       31291194     St Theresa's Ground  recreation_groun
# ...          ...                     ...               ...
# 4310  1187689780                     NaN       residential
# 4311  1187689781                     NaN       residential
# 4312  1187689785                     NaN  recreation_groun
# 4313  1188130826           IVY DREAMLAND       residential
# 4314  1188386895   Vitta Sanchay Society       residential
#
#                                                geometry
# 0     POLYGON ((72.82508 19.10217, 72.82684 19.10246...
# 1     POLYGON ((72.84234 19.11510, 72.84235 19.11552...
# 2     POLYGON ((72.81305 19.13517, 72.81314 19.13504...
# 3     POLYGON ((72.82136 19.06081, 72.82136 19.06028...
# 4     POLYGON ((72.83303 19.06316, 72.83297 19.06281...
# ...                                                 ...
# 4310  POLYGON ((72.89086 19.14789, 72.89077 19.14773...
# 4311  POLYGON ((72.89197 19.14673, 72.89256 19.14713...
# 4312  POLYGON ((72.89327 19.14757, 72.89352 19.14762...
# 4313  POLYGON ((72.82452 19.35389, 72.82555 19.35289...
# 4314  POLYGON ((72.88723 19.03118, 72.88727 19.03093...
#
# [4315 rows x 4 columns]

# %%
gdf = gdf.to_crs("EPSG:3857")

# %%
#100 meters buffer
gdf['geometry'] = gdf['geometry'].buffer(100)

# %%
import matplotlib.pyplot as plt

# Filter out 'vacant' and 'barren' types
filtered_gdf = gdf[~gdf['type'].isin(['vacant', 'barren'])]

# Plot the filtered GeoDataFrame in red
ax = filtered_gdf.plot(color='red', figsize=(10, 10))

plt.show()

# %%
gdf
# Out:
#           osm_id                    name              type  \
# 0       27036055             JW Marriott        commercial
# 1       27054927  Shopper Stop - Andheri            retail
# 2       27083476            Ranima Films       residential
# 3       31144246             Otters Club  recreation_groun
# 4       31291194     St Theresa's Ground  recreation_groun
# ...          ...                     ...               ...
# 4310  1187689780                     NaN       residential
# 4311  1187689781                     NaN       residential
# 4312  1187689785                     NaN  recreation_groun
# 4313  1188130826           IVY DREAMLAND       residential
# 4314  1188386895   Vitta Sanchay Society       residential
#
#                                                geometry
# 0     POLYGON ((8106753.109 2166946.977, 8106751.479...
# 1     POLYGON ((8108672.537 2168479.525, 8108671.852...
# 2     POLYGON ((8105461.291 2170942.685, 8105481.918...
# 3     POLYGON ((8106437.694 2162196.343, 8106505.710...
# 4     POLYGON ((8107747.978 2162472.887, 8107818.654...
# ...                                                 ...
# 4310  POLYGON ((8114139.000 2172198.314, 8114125.823...
# 4311  POLYGON ((8114207.865 2172173.104, 8114190.844...
# 4312  POLYGON ((8114385.641 2172400.517, 8114394.067...
# 4313  POLYGON ((8106744.659 2196735.713, 8106913.007...
# 4314  POLYGON ((8113782.925 2158706.024, 8113827.620...
#
# [4315 rows x 4 columns]

# %%
import re
import pandas as pd

def get_suitable_area(shapefile_path):
    """
    params : shapefile_path : location where shp files for the geolocations are present
    
    output : Geodataframe with features needed to be considered along with a buffer of 100 meters
    
    """
    
    gdfs = []
    
    #shapefile_path = "/home/smitesh22/Data/GIS Extracted/N19E072_wgs84/planet_72,19_73,20-shp/shape/landuse.shp"
    
    #get all the shapefiles available for the geolocation
    shape_files = glob.glob(f'{shapefile_path}*.shp')
    
    #loop over each shape file
    for shape_file in shape_files:
        
        match = re.search(r'([^/]+)\.shp$', shape_file)
        #feature to identiy layer
        feature = match.group(1)
        
        gdf = gpd.read_file(shapefile_path)
        
        #EPSG:3395 (World Mercator) uses metric system
        gdf = gdf.to_crs(epsg=3395)
        
        #add a buffer of 100 meters
        gdf['geometry'] = gdf['geometry'].buffer(1000)
        
        #conditions on each layer to select CERTAIN attribute values only
        if feature == "places":
            pass
        elif feature == "landuse":
            filtered_gdf = gdf[~gdf['type'].isin(['vacant', 'barren'])]
        elif feature == "natural":
            pass
        
        filtered_gdf = gdf
        
        filtered_gdf['feature'] = feature
        
        gdfs.append(filtered_gdf)
        
        # Concatenate all the GeoDataFrames in the list
        combined_gdf = pd.concat(gdfs, ignore_index=True)
        
        print(combined_gdf)
    return combined_gdf

# %%
combined_gdf = get_suitable_area("/home/smitesh22/Data/GIS Extracted/N09E092_wgs84/planet_92,9_93,10-shp/shape/")
# Out:
#       osm_id                name      type  population  \
# 0  316633967  Ten Degree Channel  locality         NaN
# 1  316633971  U-rèk-ka (Malacca)   village         NaN
# 2 -459335689               Sawal   village         NaN
# 3 -459335688             Tee Top   village         NaN
#
#                                             geometry feature
# 0  POLYGON ((10309975.468 1097926.373, 10309974.9...  places
# 1  POLYGON ((10333400.517 1018895.207, 10333400.0...  places
# 2  POLYGON ((10322362.878 1022623.662, 10322362.3...  places
# 3  POLYGON ((10322961.320 1023230.873, 10322960.8...  places
#       osm_id                name      type  population  \
# 0  316633967  Ten Degree Channel  locality         NaN
# 1  316633971  U-rèk-ka (Malacca)   village         NaN
# 2 -459335689               Sawal   village         NaN
# 3 -459335688             Tee Top   village         NaN
# 4  316633967  Ten Degree Channel  locality         NaN
# 5  316633971  U-rèk-ka (Malacca)   village         NaN
# 6 -459335689               Sawal   village         NaN
# 7 -459335688             Tee Top   village         NaN
#
#                                             geometry   feature
# 0  POLYGON ((10309975.468 1097926.373, 10309974.9...    places
# 1  POLYGON ((10333400.517 1018895.207, 10333400.0...    places
# 2  POLYGON ((10322362.878 1022623.662, 10322362.3...    places
# 3  POLYGON ((10322961.320 1023230.873, 10322960.8...    places
# 4  POLYGON ((10309975.468 1097926.373, 10309974.9...  railways
# 5  POLYGON ((10333400.517 1018895.207, 10333400.0...  railways
# 6  POLYGON ((10322362.878 1022623.662, 10322362.3...  railways
# 7  POLYGON ((10322961.320 1023230.873, 10322960.8...  railways
#        osm_id                name      type  population  \
# 0   316633967  Ten Degree Channel  locality         NaN
# 1   316633971  U-rèk-ka (Malacca)   village         NaN
# 2  -459335689               Sawal   village         NaN
# 3  -459335688             Tee Top   village         NaN
# 4   316633967  Ten Degree Channel  locality         NaN
# 5   316633971  U-rèk-ka (Malacca)   village         NaN
# 6  -459335689               Sawal   village         NaN
# 7  -459335688             Tee Top   village         NaN
# 8   316633967  Ten Degree Channel  locality         NaN
# 9   316633971  U-rèk-ka (Malacca)   village         NaN
# 10 -459335689               Sawal   village         NaN
# 11 -459335688             Tee Top   village         NaN
#
#                                              geometry   feature
# 0   POLYGON ((10309975.468 1097926.373, 10309974.9...    places
# 1   POLYGON ((10333400.517 1018895.207, 10333400.0...    places
# 2   POLYGON ((10322362.878 1022623.662, 10322362.3...    places
# 3   POLYGON ((10322961.320 1023230.873, 10322960.8...    places
# 4   POLYGON ((10309975.468 1097926.373, 10309974.9...  railways
# 5   POLYGON ((10333400.517 1018895.207, 10333400.0...  railways
# 6   POLYGON ((10322362.878 1022623.662, 10322362.3...  railways
# 7   POLYGON ((10322961.320 1023230.873, 10322960.8...  railways
# 8   POLYGON ((10309975.468 1097926.373, 10309974.9...   landuse
# 9   POLYGON ((10333400.517 1018895.207, 10333400.0...   landuse
# 10  POLYGON ((10322362.878 1022623.662, 10322362.3...   landuse
# 11  POLYGON ((10322961.320 1023230.873, 10322960.8...   landuse
#        osm_id                name      type  population  \
# 0   316633967  Ten Degree Channel  locality         NaN
# 1   316633971  U-rèk-ka (Malacca)   village         NaN
# 2  -459335689               Sawal   village         NaN
# 3  -459335688             Tee Top   village         NaN
# 4   316633967  Ten Degree Channel  locality         NaN
# 5   316633971  U-rèk-ka (Malacca)   village         NaN
# 6  -459335689               Sawal   village         NaN
# 7  -459335688             Tee Top   village         NaN
# 8   316633967  Ten Degree Channel  locality         NaN
# 9   316633971  U-rèk-ka (Malacca)   village         NaN
# 10 -459335689               Sawal   village         NaN
# 11 -459335688             Tee Top   village         NaN
# 12  316633967  Ten Degree Channel  locality         NaN
# 13  316633971  U-rèk-ka (Malacca)   village         NaN
# 14 -459335689               Sawal   village         NaN
# 15 -459335688             Tee Top   village         NaN
#
#                                              geometry   feature
# 0   POLYGON ((10309975.468 1097926.373, 10309974.9...    places
# 1   POLYGON ((10333400.517 1018895.207, 10333400.0...    places
# 2   POLYGON ((10322362.878 1022623.662, 10322362.3...    places
# 3   POLYGON ((10322961.320 1023230.873, 10322960.8...    places
# 4   POLYGON ((10309975.468 1097926.373, 10309974.9...  railways
# 5   POLYGON ((10333400.517 1018895.207, 10333400.0...  railways
# 6   POLYGON ((10322362.878 1022623.662, 10322362.3...  railways
# 7   POLYGON ((10322961.320 1023230.873, 10322960.8...  railways
# 8   POLYGON ((10309975.468 1097926.373, 10309974.9...   landuse
# 9   POLYGON ((10333400.517 1018895.207, 10333400.0...   landuse
# 10  POLYGON ((10322362.878 1022623.662, 10322362.3...   landuse
# 11  POLYGON ((10322961.320 1023230.873, 10322960.8...   landuse
# 12  POLYGON ((10309975.468 1097926.373, 10309974.9...   natural
# 13  POLYGON ((10333400.517 1018895.207, 10333400.0...   natural
# 14  POLYGON ((10322362.878 1022623.662, 10322362.3...   natural
# 15  POLYGON ((10322961.320 1023230.873, 10322960.8...   natural
#        osm_id                name      type  population  \
# 0   316633967  Ten Degree Channel  locality         NaN
# 1   316633971  U-rèk-ka (Malacca)   village         NaN
# 2  -459335689               Sawal   village         NaN
# 3  -459335688             Tee Top   village         NaN
# 4   316633967  Ten Degree Channel  locality         NaN
# 5   316633971  U-rèk-ka (Malacca)   village         NaN
# 6  -459335689               Sawal   village         NaN
# 7  -459335688             Tee Top   village         NaN
# 8   316633967  Ten Degree Channel  locality         NaN
# 9   316633971  U-rèk-ka (Malacca)   village         NaN
# 10 -459335689               Sawal   village         NaN
# 11 -459335688             Tee Top   village         NaN
# 12  316633967  Ten Degree Channel  locality         NaN
# 13  316633971  U-rèk-ka (Malacca)   village         NaN
# 14 -459335689               Sawal   village         NaN
# 15 -459335688             Tee Top   village         NaN
# 16  316633967  Ten Degree Channel  locality         NaN
# 17  316633971  U-rèk-ka (Malacca)   village         NaN
# 18 -459335689               Sawal   village         NaN
# 19 -459335688             Tee Top   village         NaN
#
#                                              geometry   feature
# 0   POLYGON ((10309975.468 1097926.373, 10309974.9...    places
# 1   POLYGON ((10333400.517 1018895.207, 10333400.0...    places
# 2   POLYGON ((10322362.878 1022623.662, 10322362.3...    places
# 3   POLYGON ((10322961.320 1023230.873, 10322960.8...    places
# 4   POLYGON ((10309975.468 1097926.373, 10309974.9...  railways
# 5   POLYGON ((10333400.517 1018895.207, 10333400.0...  railways
# 6   POLYGON ((10322362.878 1022623.662, 10322362.3...  railways
# 7   POLYGON ((10322961.320 1023230.873, 10322960.8...  railways
# 8   POLYGON ((10309975.468 1097926.373, 10309974.9...   landuse
# 9   POLYGON ((10333400.517 1018895.207, 10333400.0...   landuse
# 10  POLYGON ((10322362.878 1022623.662, 10322362.3...   landuse
# 11  POLYGON ((10322961.320 1023230.873, 10322960.8...   landuse
# 12  POLYGON ((10309975.468 1097926.373, 10309974.9...   natural
# 13  POLYGON ((10333400.517 1018895.207, 10333400.0...   natural
# 14  POLYGON ((10322362.878 1022623.662, 10322362.3...   natural
# 15  POLYGON ((10322961.320 1023230.873, 10322960.8...   natural
# 16  POLYGON ((10309975.468 1097926.373, 10309974.9...    points
# 17  POLYGON ((10333400.517 1018895.207, 10333400.0...    points
# 18  POLYGON ((10322362.878 1022623.662, 10322362.3...    points
# 19  POLYGON ((10322961.320 1023230.873, 10322960.8...    points
#        osm_id                name      type  population  \
# 0   316633967  Ten Degree Channel  locality         NaN
# 1   316633971  U-rèk-ka (Malacca)   village         NaN
# 2  -459335689               Sawal   village         NaN
# 3  -459335688             Tee Top   village         NaN
# 4   316633967  Ten Degree Channel  locality         NaN
# 5   316633971  U-rèk-ka (Malacca)   village         NaN
# 6  -459335689               Sawal   village         NaN
# 7  -459335688             Tee Top   village         NaN
# 8   316633967  Ten Degree Channel  locality         NaN
# 9   316633971  U-rèk-ka (Malacca)   village         NaN
# 10 -459335689               Sawal   village         NaN
# 11 -459335688             Tee Top   village         NaN
# 12  316633967  Ten Degree Channel  locality         NaN
# 13  316633971  U-rèk-ka (Malacca)   village         NaN
# 14 -459335689               Sawal   village         NaN
# 15 -459335688             Tee Top   village         NaN
# 16  316633967  Ten Degree Channel  locality         NaN
# 17  316633971  U-rèk-ka (Malacca)   village         NaN
# 18 -459335689               Sawal   village         NaN
# 19 -459335688             Tee Top   village         NaN
# 20  316633967  Ten Degree Channel  locality         NaN
# 21  316633971  U-rèk-ka (Malacca)   village         NaN
# 22 -459335689               Sawal   village         NaN
# 23 -459335688             Tee Top   village         NaN
#
#                                              geometry    feature
# 0   POLYGON ((10309975.468 1097926.373, 10309974.9...     places
# 1   POLYGON ((10333400.517 1018895.207, 10333400.0...     places
# 2   POLYGON ((10322362.878 1022623.662, 10322362.3...     places
# 3   POLYGON ((10322961.320 1023230.873, 10322960.8...     places
# 4   POLYGON ((10309975.468 1097926.373, 10309974.9...   railways
# 5   POLYGON ((10333400.517 1018895.207, 10333400.0...   railways
# 6   POLYGON ((10322362.878 1022623.662, 10322362.3...   railways
# 7   POLYGON ((10322961.320 1023230.873, 10322960.8...   railways
# 8   POLYGON ((10309975.468 1097926.373, 10309974.9...    landuse
# 9   POLYGON ((10333400.517 1018895.207, 10333400.0...    landuse
# 10  POLYGON ((10322362.878 1022623.662, 10322362.3...    landuse
# 11  POLYGON ((10322961.320 1023230.873, 10322960.8...    landuse
# 12  POLYGON ((10309975.468 1097926.373, 10309974.9...    natural
# 13  POLYGON ((10333400.517 1018895.207, 10333400.0...    natural
# 14  POLYGON ((10322362.878 1022623.662, 10322362.3...    natural
# 15  POLYGON ((10322961.320 1023230.873, 10322960.8...    natural
# 16  POLYGON ((10309975.468 1097926.373, 10309974.9...     points
# 17  POLYGON ((10333400.517 1018895.207, 10333400.0...     points
# 18  POLYGON ((10322362.878 1022623.662, 10322362.3...     points
# 19  POLYGON ((10322961.320 1023230.873, 10322960.8...     points
# 20  POLYGON ((10309975.468 1097926.373, 10309974.9...  waterways
# 21  POLYGON ((10333400.517 1018895.207, 10333400.0...  waterways
# 22  POLYGON ((10322362.878 1022623.662, 10322362.3...  waterways
# 23  POLYGON ((10322961.320 1023230.873, 10322960.8...  waterways
#        osm_id                name      type  population  \
# 0   316633967  Ten Degree Channel  locality         NaN
# 1   316633971  U-rèk-ka (Malacca)   village         NaN
# 2  -459335689               Sawal   village         NaN
# 3  -459335688             Tee Top   village         NaN
# 4   316633967  Ten Degree Channel  locality         NaN
# 5   316633971  U-rèk-ka (Malacca)   village         NaN
# 6  -459335689               Sawal   village         NaN
# 7  -459335688             Tee Top   village         NaN
# 8   316633967  Ten Degree Channel  locality         NaN
# 9   316633971  U-rèk-ka (Malacca)   village         NaN
# 10 -459335689               Sawal   village         NaN
# 11 -459335688             Tee Top   village         NaN
# 12  316633967  Ten Degree Channel  locality         NaN
# 13  316633971  U-rèk-ka (Malacca)   village         NaN
# 14 -459335689               Sawal   village         NaN
# 15 -459335688             Tee Top   village         NaN
# 16  316633967  Ten Degree Channel  locality         NaN
# 17  316633971  U-rèk-ka (Malacca)   village         NaN
# 18 -459335689               Sawal   village         NaN
# 19 -459335688             Tee Top   village         NaN
# 20  316633967  Ten Degree Channel  locality         NaN
# 21  316633971  U-rèk-ka (Malacca)   village         NaN
# 22 -459335689               Sawal   village         NaN
# 23 -459335688             Tee Top   village         NaN
# 24  316633967  Ten Degree Channel  locality         NaN
# 25  316633971  U-rèk-ka (Malacca)   village         NaN
# 26 -459335689               Sawal   village         NaN
# 27 -459335688             Tee Top   village         NaN
#
#                                              geometry    feature
# 0   POLYGON ((10309975.468 1097926.373, 10309974.9...     places
# 1   POLYGON ((10333400.517 1018895.207, 10333400.0...     places
# 2   POLYGON ((10322362.878 1022623.662, 10322362.3...     places
# 3   POLYGON ((10322961.320 1023230.873, 10322960.8...     places
# 4   POLYGON ((10309975.468 1097926.373, 10309974.9...   railways
# 5   POLYGON ((10333400.517 1018895.207, 10333400.0...   railways
# 6   POLYGON ((10322362.878 1022623.662, 10322362.3...   railways
# 7   POLYGON ((10322961.320 1023230.873, 10322960.8...   railways
# 8   POLYGON ((10309975.468 1097926.373, 10309974.9...    landuse
# 9   POLYGON ((10333400.517 1018895.207, 10333400.0...    landuse
# 10  POLYGON ((10322362.878 1022623.662, 10322362.3...    landuse
# 11  POLYGON ((10322961.320 1023230.873, 10322960.8...    landuse
# 12  POLYGON ((10309975.468 1097926.373, 10309974.9...    natural
# 13  POLYGON ((10333400.517 1018895.207, 10333400.0...    natural
# 14  POLYGON ((10322362.878 1022623.662, 10322362.3...    natural
# 15  POLYGON ((10322961.320 1023230.873, 10322960.8...    natural
# 16  POLYGON ((10309975.468 1097926.373, 10309974.9...     points
# 17  POLYGON ((10333400.517 1018895.207, 10333400.0...     points
# 18  POLYGON ((10322362.878 1022623.662, 10322362.3...     points
# 19  POLYGON ((10322961.320 1023230.873, 10322960.8...     points
# 20  POLYGON ((10309975.468 1097926.373, 10309974.9...  waterways
# 21  POLYGON ((10333400.517 1018895.207, 10333400.0...  waterways
# 22  POLYGON ((10322362.878 1022623.662, 10322362.3...  waterways
# 23  POLYGON ((10322961.320 1023230.873, 10322960.8...  waterways
# 24  POLYGON ((10309975.468 1097926.373, 10309974.9...      roads
# 25  POLYGON ((10333400.517 1018895.207, 10333400.0...      roads
# 26  POLYGON ((10322362.878 1022623.662, 10322362.3...      roads
# 27  POLYGON ((10322961.320 1023230.873, 10322960.8...      roads
#        osm_id                name      type  population  \
# 0   316633967  Ten Degree Channel  locality         NaN
# 1   316633971  U-rèk-ka (Malacca)   village         NaN
# 2  -459335689               Sawal   village         NaN
# 3  -459335688             Tee Top   village         NaN
# 4   316633967  Ten Degree Channel  locality         NaN
# 5   316633971  U-rèk-ka (Malacca)   village         NaN
# 6  -459335689               Sawal   village         NaN
# 7  -459335688             Tee Top   village         NaN
# 8   316633967  Ten Degree Channel  locality         NaN
# 9   316633971  U-rèk-ka (Malacca)   village         NaN
# 10 -459335689               Sawal   village         NaN
# 11 -459335688             Tee Top   village         NaN
# 12  316633967  Ten Degree Channel  locality         NaN
# 13  316633971  U-rèk-ka (Malacca)   village         NaN
# 14 -459335689               Sawal   village         NaN
# 15 -459335688             Tee Top   village         NaN
# 16  316633967  Ten Degree Channel  locality         NaN
# 17  316633971  U-rèk-ka (Malacca)   village         NaN
# 18 -459335689               Sawal   village         NaN
# 19 -459335688             Tee Top   village         NaN
# 20  316633967  Ten Degree Channel  locality         NaN
# 21  316633971  U-rèk-ka (Malacca)   village         NaN
# 22 -459335689               Sawal   village         NaN
# 23 -459335688             Tee Top   village         NaN
# 24  316633967  Ten Degree Channel  locality         NaN
# 25  316633971  U-rèk-ka (Malacca)   village         NaN
# 26 -459335689               Sawal   village         NaN
# 27 -459335688             Tee Top   village         NaN
# 28  316633967  Ten Degree Channel  locality         NaN
# 29  316633971  U-rèk-ka (Malacca)   village         NaN
# 30 -459335689               Sawal   village         NaN
# 31 -459335688             Tee Top   village         NaN
#
#                                              geometry    feature
# 0   POLYGON ((10309975.468 1097926.373, 10309974.9...     places
# 1   POLYGON ((10333400.517 1018895.207, 10333400.0...     places
# 2   POLYGON ((10322362.878 1022623.662, 10322362.3...     places
# 3   POLYGON ((10322961.320 1023230.873, 10322960.8...     places
# 4   POLYGON ((10309975.468 1097926.373, 10309974.9...   railways
# 5   POLYGON ((10333400.517 1018895.207, 10333400.0...   railways
# 6   POLYGON ((10322362.878 1022623.662, 10322362.3...   railways
# 7   POLYGON ((10322961.320 1023230.873, 10322960.8...   railways
# 8   POLYGON ((10309975.468 1097926.373, 10309974.9...    landuse
# 9   POLYGON ((10333400.517 1018895.207, 10333400.0...    landuse
# 10  POLYGON ((10322362.878 1022623.662, 10322362.3...    landuse
# 11  POLYGON ((10322961.320 1023230.873, 10322960.8...    landuse
# 12  POLYGON ((10309975.468 1097926.373, 10309974.9...    natural
# 13  POLYGON ((10333400.517 1018895.207, 10333400.0...    natural
# 14  POLYGON ((10322362.878 1022623.662, 10322362.3...    natural
# 15  POLYGON ((10322961.320 1023230.873, 10322960.8...    natural
# 16  POLYGON ((10309975.468 1097926.373, 10309974.9...     points
# 17  POLYGON ((10333400.517 1018895.207, 10333400.0...     points
# 18  POLYGON ((10322362.878 1022623.662, 10322362.3...     points
# 19  POLYGON ((10322961.320 1023230.873, 10322960.8...     points
# 20  POLYGON ((10309975.468 1097926.373, 10309974.9...  waterways
# 21  POLYGON ((10333400.517 1018895.207, 10333400.0...  waterways
# 22  POLYGON ((10322362.878 1022623.662, 10322362.3...  waterways
# 23  POLYGON ((10322961.320 1023230.873, 10322960.8...  waterways
# 24  POLYGON ((10309975.468 1097926.373, 10309974.9...      roads
# 25  POLYGON ((10333400.517 1018895.207, 10333400.0...      roads
# 26  POLYGON ((10322362.878 1022623.662, 10322362.3...      roads
# 27  POLYGON ((10322961.320 1023230.873, 10322960.8...      roads
# 28  POLYGON ((10309975.468 1097926.373, 10309974.9...  buildings
# 29  POLYGON ((10333400.517 1018895.207, 10333400.0...  buildings
# 30  POLYGON ((10322362.878 1022623.662, 10322362.3...  buildings
# 31  POLYGON ((10322961.320 1023230.873, 10322960.8...  buildings

# %%
combined_gdf
# Out:
#        osm_id                name      type  population  \
# 0   316633967  Ten Degree Channel  locality         NaN
# 1   316633971  U-rèk-ka (Malacca)   village         NaN
# 2  -459335689               Sawal   village         NaN
# 3  -459335688             Tee Top   village         NaN
# 4   316633967  Ten Degree Channel  locality         NaN
# 5   316633971  U-rèk-ka (Malacca)   village         NaN
# 6  -459335689               Sawal   village         NaN
# 7  -459335688             Tee Top   village         NaN
# 8   316633967  Ten Degree Channel  locality         NaN
# 9   316633971  U-rèk-ka (Malacca)   village         NaN
# 10 -459335689               Sawal   village         NaN
# 11 -459335688             Tee Top   village         NaN
# 12  316633967  Ten Degree Channel  locality         NaN
# 13  316633971  U-rèk-ka (Malacca)   village         NaN
# 14 -459335689               Sawal   village         NaN
# 15 -459335688             Tee Top   village         NaN
# 16  316633967  Ten Degree Channel  locality         NaN
# 17  316633971  U-rèk-ka (Malacca)   village         NaN
# 18 -459335689               Sawal   village         NaN
# 19 -459335688             Tee Top   village         NaN
# 20  316633967  Ten Degree Channel  locality         NaN
# 21  316633971  U-rèk-ka (Malacca)   village         NaN
# 22 -459335689               Sawal   village         NaN
# 23 -459335688             Tee Top   village         NaN
# 24  316633967  Ten Degree Channel  locality         NaN
# 25  316633971  U-rèk-ka (Malacca)   village         NaN
# 26 -459335689               Sawal   village         NaN
# 27 -459335688             Tee Top   village         NaN
# 28  316633967  Ten Degree Channel  locality         NaN
# 29  316633971  U-rèk-ka (Malacca)   village         NaN
# 30 -459335689               Sawal   village         NaN
# 31 -459335688             Tee Top   village         NaN
#
#                                              geometry    feature
# 0   POLYGON ((10309975.468 1097926.373, 10309974.9...     places
# 1   POLYGON ((10333400.517 1018895.207, 10333400.0...     places
# 2   POLYGON ((10322362.878 1022623.662, 10322362.3...     places
# 3   POLYGON ((10322961.320 1023230.873, 10322960.8...     places
# 4   POLYGON ((10309975.468 1097926.373, 10309974.9...   railways
# 5   POLYGON ((10333400.517 1018895.207, 10333400.0...   railways
# 6   POLYGON ((10322362.878 1022623.662, 10322362.3...   railways
# 7   POLYGON ((10322961.320 1023230.873, 10322960.8...   railways
# 8   POLYGON ((10309975.468 1097926.373, 10309974.9...    landuse
# 9   POLYGON ((10333400.517 1018895.207, 10333400.0...    landuse
# 10  POLYGON ((10322362.878 1022623.662, 10322362.3...    landuse
# 11  POLYGON ((10322961.320 1023230.873, 10322960.8...    landuse
# 12  POLYGON ((10309975.468 1097926.373, 10309974.9...    natural
# 13  POLYGON ((10333400.517 1018895.207, 10333400.0...    natural
# 14  POLYGON ((10322362.878 1022623.662, 10322362.3...    natural
# 15  POLYGON ((10322961.320 1023230.873, 10322960.8...    natural
# 16  POLYGON ((10309975.468 1097926.373, 10309974.9...     points
# 17  POLYGON ((10333400.517 1018895.207, 10333400.0...     points
# 18  POLYGON ((10322362.878 1022623.662, 10322362.3...     points
# 19  POLYGON ((10322961.320 1023230.873, 10322960.8...     points
# 20  POLYGON ((10309975.468 1097926.373, 10309974.9...  waterways
# 21  POLYGON ((10333400.517 1018895.207, 10333400.0...  waterways
# 22  POLYGON ((10322362.878 1022623.662, 10322362.3...  waterways
# 23  POLYGON ((10322961.320 1023230.873, 10322960.8...  waterways
# 24  POLYGON ((10309975.468 1097926.373, 10309974.9...      roads
# 25  POLYGON ((10333400.517 1018895.207, 10333400.0...      roads
# 26  POLYGON ((10322362.878 1022623.662, 10322362.3...      roads
# 27  POLYGON ((10322961.320 1023230.873, 10322960.8...      roads
# 28  POLYGON ((10309975.468 1097926.373, 10309974.9...  buildings
# 29  POLYGON ((10333400.517 1018895.207, 10333400.0...  buildings
# 30  POLYGON ((10322362.878 1022623.662, 10322362.3...  buildings
# 31  POLYGON ((10322961.320 1023230.873, 10322960.8...  buildings

# %%
combined_gdf.plot(color='red')

# Optional: Add titles, labels, or other customizations
plt.title('My Geospatial Plot')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()

# %%
# Out:
# {'places': {'borough',
#   'city',
#   'farm',
#   'hamlet',
#   'island',
#   'locality',
#   'neighbourhood',
#   'plot',
#   'suburb',
#   'town',
#   'village',
#   'yes'},
#  'railway': {'abandoned',
#   'construction',
#   'disused',
#   'miniature',
#   'monorail',
#   'platform',
#   'platform_edge',
#   'proposed',
#   'rail',
#   'subway',
#   'traverser',
#   'turntable',
#   'workshop'},
#  'landuse': {'allotments',
#   'aquaculture',
#   'barren',
#   'basin',
#   'brownfield',
#   'cemetery',
#   'commercial',
#   'construction',
#   'education',
#   'farmland',
#   'farmyard',
#   'garages',
#   'garden',
#   'grass',
#   'green',
#   'greenfield',
#   'industrial',
#   'landfill',
#   'meadow',
#   'military',
#   'orchard',
#   'parking',
#   'plant_nursery',
#   'quarry',
#   'railway',
#   'recreation_groun',
#   'religious',
#   'reservoir',
#   'residential',
#   'retail',
#   'salt_pond',
#   'saltpond',
#   'used by school a',
#   'vacant',
#   'village_green',
#   'yes'},
#  'natural': {'forest', 'park', 'water'},
#  'point': {'Drinking Water F',
#   'The Wall',
#   'animal_boarding',
#   'animal_shelter',
#   'antenna',
#   'apartment',
#   'archaeological_s',
#   'art_school',
#   'arts_centre',
#   'artwork',
#   'atm',
#   'attraction',
#   'bank',
#   'bar',
#   'battlefield',
#   'bbq',
#   'beauty',
#   'bench',
#   'bicycle_parking',
#   'bicycle_repair_s',
#   'blood_bank',
#   'buffer_stop',
#   'bureau_de_change',
#   'bus_station',
#   'bus_stop',
#   'cafe',
#   'camp_site',
#   'car_rental',
#   'car_wash',
#   'castle',
#   'charging_station',
#   'childcare',
#   'chimney',
#   'cinema',
#   'clinic',
#   'clothes',
#   'clubhouse',
#   'college',
#   'community_centre',
#   'compressed_air',
#   'construction',
#   'coworking_space',
#   'crane',
#   'crematorium',
#   'cross',
#   'crossing',
#   'dancing_school',
#   'dentist',
#   'derail',
#   'doctors',
#   'drinking_water',
#   'driving_school',
#   'electronics',
#   'electronics_repa',
#   'elevator',
#   'events_venue',
#   'fast_food',
#   'ferry_terminal',
#   'fire_station',
#   'flagpole',
#   'food_court',
#   'fort',
#   'fountain',
#   'fuel',
#   'gallery',
#   'guest_house',
#   'health_post',
#   'hospital',
#   'hostel',
#   'hotel',
#   'hunting_stand',
#   'ice_cream',
#   'information',
#   'internet_cafe',
#   'jeweller',
#   'kindergarten',
#   'language_school',
#   'level_crossing',
#   'library',
#   'lighthouse',
#   'marketplace',
#   'mast',
#   'memorial',
#   'mess',
#   'mini_roundabout',
#   'monument',
#   'motel',
#   'motorcycle_parki',
#   'motorway_junctio',
#   'museum',
#   'nightclub',
#   'parking',
#   'parking_entrance',
#   'passing_place',
#   'pharmacy',
#   'phone service pr',
#   'picnic_site',
#   'place_of_worship',
#   'platform',
#   'police',
#   'post_box',
#   'post_office',
#   'prep_school',
#   'pub',
#   'public',
#   'public_building',
#   'railway_crossing',
#   'reception_desk',
#   'rest_area',
#   'restaurant',
#   'ruins',
#   'school',
#   'shelter',
#   'signal',
#   'social_centre',
#   'social_facility',
#   'spa',
#   'station',
#   'steps',
#   'stop',
#   'storage_tank',
#   'street_lamp',
#   'studio',
#   'subway_entrance',
#   'surveillance',
#   'switch',
#   'taxi',
#   'technical_statio',
#   'telephone',
#   'telephone_exchan',
#   'theatre',
#   'theme_park',
#   'toilets',
#   'toll_gantry',
#   'tomb',
#   'tower',
#   'townhall',
#   'traffic_signals',
#   'training',
#   'turning_circle',
#   'turning_loop',
#   'unclassified',
#   'university',
#   'vending_machine',
#   'veterinary',
#   'viewpoint',
#   'waste_basket',
#   'waste_disposal',
#   'water_point',
#   'water_tap',
#   'water_tower',
#   'water_well',
#   'wayside_cross',
#   'wayside_shrine',
#   'works',
#   'wreck',
#   'yes'},
#  'waterway': {'canal', 'dam', 'dock', 'drain', 'river', 'stream', 'weir'},
#  'road': {'bridleway',
#   'bus_stop',
#   'construction',
#   'cycleway',
#   'elevator',
#   'footway',
#   'living_street',
#   'motorway',
#   'motorway_link',
#   'path',
#   'pedestrian',
#   'primary',
#   'primary_link',
#   'proposed',
#   'residential',
#   'secondary',
#   'secondary_link',
#   'service',
#   'services',
#   'steps',
#   'tertiary',
#   'tertiary_link',
#   'track',
#   'trunk',
#   'trunk_link',
#   'unclassified'},
#  'buildings': {'Chemtex_House',
#   'NVR Hospital',
#   None,
#   'SHIV AANGAN BUIL',
#   'apartment',
#   'apartments',
#   'aquarium',
#   'arts_centre',
#   'attraction',
#   'bank',
#   'bar',
#   'blood_bank',
#   'building',
#   'bungalow',
#   'bus_station',
#   'cabin',
#   'cafe',
#   'canteen',
#   'car_wash',
#   'central_office',
#   'chapel',
#   'childcare',
#   'church',
#   'cinema',
#   'city_gate',
#   'civic',
#   'clinic',
#   'clubhouse',
#   'collapsed',
#   'college',
#   'commercial',
#   'community_centre',
#   'construction',
#   'courthouse',
#   'cowshed',
#   'depot',
#   'detached',
#   'dormitory',
#   'events_venue',
#   'factory',
#   'fast_food',
#   'ferry_terminal',
#   'fire_station',
#   'food_court',
#   'fort',
#   'fuel',
#   'gallery',
#   'garage',
#   'government',
#   'greenhouse',
#   'guest_house',
#   'hangar',
#   'hospital',
#   'hostel',
#   'hotel',
#   'house',
#   'hut',
#   'industrial',
#   'kindergarten',
#   'library',
#   'lighthouse',
#   'mall',
#   'manufacture',
#   'marketplace',
#   'memorial',
#   'mosque',
#   'motel',
#   'motorcycle_parki',
#   'no',
#   'office',
#   'outdoor',
#   'parking',
#   'part',
#   'pharmacy',
#   'pier',
#   'place_of_worship',
#   'police',
#   'post_office',
#   'prep_school',
#   'public',
#   'public_building',
#   'pumping_station',
#   'residential',
#   'restaurant',
#   'retail',
#   'roof',
#   'ruins',
#   'school',
#   'service',
#   'shed',
#   'shelter',
#   'shop',
#   'social_centre',
#   'social_facility',
#   'sports_centre',
#   'stadium',
#   'stage',
#   'storage_tank',
#   'stupa',
#   'substation',
#   'supermarket',
#   'temple',
#   'terrace',
#   'theatre',
#   'toilets',
#   'tomb',
#   'tower',
#   'townhall',
#   'train_station',
#   'transportation',
#   'undefined',
#   'university',
#   'veterinary',
#   'wall',
#   'warehouse',
#   'water_tower',
#   'works',
#   'workshop',
#   'yes',
#   'yes,_hotel,_comm'}}
